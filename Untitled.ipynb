# %% [markdown]
# Write a function called greet that takes a name argument and returns a greeting string. It should work like this in the terminal:
# Guys Try other way too

# %%
def greet(x):
  return ('Hello, '+x+'!')
if __name__ == '__main__':
  print(greet('World'))
  print(greet('Grok'))
  print(greet('123'))
# Out:
# Hello, World!
# Hello, Grok!
# Hello, 123!

# %% [markdown]
# You can protect your testing code using this trick:

# %%
def add(a, b):
  return a + b
  
if __name__ == '__main__':
  print(add(2, 3))
  print(add(1, 5))
# Out:
# 5
# 6

# %% [markdown]
# Let's start with a program to calculate the mean of a set of numbers stored in a Python list.
# The mean function in the Python statistics module works like this:

# %%
from statistics import mean
fluxes = [23.3, 42.1, 2.0, -3.2, 55.6]
m = mean(fluxes)
print(m)
# Out:
# 23.96

# %% [markdown]
# or we could calculate the mean manually:

# %%
fluxes = [23.3, 42.1, 2.0, -3.2, 55.6]
m = sum(fluxes)/len(fluxes)
print(m)
# Out:
# 23.96

# %% [markdown]
# Tables are often stored in comma-separated values (CSV) format. You can use Python's built-in string functions to read a CSV file into a list and process it.

# %%
data = []
for line in open('basic.csv'):
  data.append(line.strip().split(','))

print(data)

# %% [markdown]
# other way is using the loadtxt

# %%
import numpy as np
data = np.loadtxt('basic.csv', delimiter=',')
print(data)

# %% [markdown]
# Try implementing mean and median(np.mean, np.median), round it to one decimal xD
